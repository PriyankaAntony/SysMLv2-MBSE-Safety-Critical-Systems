# %%
package usageElement{
 part HAP{
part flightstructure  {
attribute mass;
    perform action provideThrust;
}
part payload{
    part camera[3];
}
}
}
# Out:
# Package usageElement (ad384d40-b2a2-4880-b364-067544e09162)

# %%
%viz usageElement

# %%
package usageElement{
     part HAP{
         part flightstructure  {
           attribute mass;
           perform action provideThrust;
     }
      part payload{
          part camera[3];
     }
   }
}
# Out:
# Package usageElement (3a4e97a3-184f-4659-9ba1-66eda065be36)

# %%
%viz usageElement
