# %%
package PowerAnalysis {
    import ISQ::*;
    import SI::*;
    import ScalarValues::*;
    part def HighAltitudePlatform {
       
        attribute solarEnergy = 40800; //Wh 
        attribute batteryPower = 49992; //Wh
        attribute calculatedTotal : Real= solarEnergy + batteryPower;     
    analysis def PowerSumVerification {
        subject platform : HighAltitudePlatform;
        return isPowerCorrect : Boolean =(platform.calculatedTotal == 90792 ); //Wh
        
        objective PowerCheckObjective {
            /*
            * The objective of this analysis is to determine whether the
            * subject high altitude platform can satisfy the energy requirement <'CR2.3'> PowerSubsystem.
            */
            }
        }
        
    }
}
# Out:
# Package PowerAnalysis (1f417871-5d00-47a5-8b8f-7cceb6e15791)

# %%
%eval PowerAnalysis::HighAltitudePlatform::PowerSumVerification::isPowerCorrect
# Out:
# LiteralBoolean true (93479bcf-c60f-405e-ae03-a8f5f824b6e3)

# %%
%eval  PowerAnalysis::HighAltitudePlatform::calculatedTotal
# Out:
# LiteralInteger 90792 (f8f92e12-fbd8-4682-83ba-7932f914465d)

# %%
%viz --view MIXED --style EVAL PowerAnalysis
