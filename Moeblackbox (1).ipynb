# %%
package MeasuresOfEffectiveness{
   part def HAPsystem {
        import ISQ::*;
        import ScalarValues::Integer;
        import ScalarValues::Real;   
        
        attribute weight : Real;
        attribute data :Integer; 
        attribute datadistance :Integer;
        attribute power: Integer;
        attribute temperature : Real;
        attribute altitude :Integer;
        attribute minAltitudeMargin: Integer;
       
     part def Safety {
         attribute redefines altitude: Real;
         altitude =56000;
         attribute redefines minAltitudeMargin: Real;
         minAltitudeMargin = 16000;
         attribute stabilityTime : Real;   
         stabilityTime = 2;
         
    }
   }
}
# Out:
# WARNING:Duplicate of other element name (1.sysml line : 16 column : 10)
# WARNING:Must be an accessible feature (use dot notation for nesting) (1.sysml line : 16 column : 30)
# WARNING:Duplicate of other element name (1.sysml line : 17 column : 10)
# WARNING:Duplicate of other element name (1.sysml line : 18 column : 10)
# WARNING:Must be an accessible feature (use dot notation for nesting) (1.sysml line : 18 column : 30)
# WARNING:Duplicate of other element name (1.sysml line : 19 column : 10)
# WARNING:Duplicate of other element name (1.sysml line : 20 column : 20)
# WARNING:Duplicate of other element name (1.sysml line : 21 column : 10)
# Package MeasuresOfEffectiveness (42451942-d9aa-4b62-9524-b0d10e63de1a)

# %%
%viz --style LR MeasuresOfEffectiveness

# %%
//satisfy safety.operationalAltitude -> requirement::SN1_3;

# %%
package MeasuresOfEffectiveness{
   part def HAPsystem {
        import ISQ::*;
        import ScalarValues::Integer;
        import ScalarValues::Real; 
        
       
        
        attribute weight : Real;
        attribute data :Integer; 
        attribute datadistance :Integer;
        attribute power: Integer;
        attribute temperature : Real;
        attribute altitude :Integer;
        attribute minAltitudeMargin: Integer;
        attribute altitudeStatusFlag: Integer;
        attribute altitudeReading: Integer;
        attribute minAltitudeMarginChecker: Integer;
        attribute requiredStableTime: Integer;
        
       
     part def Safety {
         attribute redefines altitude: Real;
         altitude =56000;
         attribute redefines minAltitudeMargin: Real;
         minAltitudeMargin = 16000;
         attribute stabilityTime : Real;   
         stabilityTime = 2;
         
         
    }
   }
}
# Out:
# WARNING:Duplicate of other element name (6.sysml line : 23 column : 10)
# WARNING:Must be an accessible feature (use dot notation for nesting) (6.sysml line : 23 column : 30)
# WARNING:Duplicate of other element name (6.sysml line : 24 column : 10)
# WARNING:Duplicate of other element name (6.sysml line : 25 column : 10)
# WARNING:Must be an accessible feature (use dot notation for nesting) (6.sysml line : 25 column : 30)
# WARNING:Duplicate of other element name (6.sysml line : 26 column : 10)
# WARNING:Duplicate of other element name (6.sysml line : 27 column : 20)
# WARNING:Duplicate of other element name (6.sysml line : 28 column : 10)
# Package MeasuresOfEffectiveness (7c3b3661-168b-4039-9e01-a59725154a25)

# %%
package MeasuresOfEffectiveness{
   part def HAPsystem {
        import ISQ::*;
        import ScalarValues::Integer;
        import ScalarValues::Real;   
        
        attribute weight : Real;
        attribute data :Integer; 
        attribute datadistance :Integer;
        attribute power: Integer;
        attribute temperature : Real;
        attribute altitude :Integer;
      
       
     part def Safety {
         attribute redefines altitude: Real;
         altitude =56000;
    }
   }
}
# Out:
# WARNING:Duplicate of other element name (1.sysml line : 16 column : 10)
# WARNING:Must be an accessible feature (use dot notation for nesting) (1.sysml line : 16 column : 30)
# WARNING:Duplicate of other element name (1.sysml line : 17 column : 10)
# Package MeasuresOfEffectiveness (008e3ba7-dbc6-4f99-a4c8-81ca24f98e4a)

# %%
%viz --style LR MeasuresOfEffectiveness

# %%
%viz LR MeasuresOfEffectiveness
# Out:
# ERROR:Couldn't resolve reference to Element 'LR'
