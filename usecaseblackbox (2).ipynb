# %%
package HAPUse {

    part def HAPSystem;
    part def researchers;
    part def groundStationControl;
    part def Person;
    part def payload;
    part def Environment;
    part def HAP;
    part def platform;
}
# Out:
# Package HAPUse (18671dbc-1248-4d79-ab6b-c7667b2e24bb)

# %%
package HAPUseCaseForData {    
import HAPUse::*;
    part HAP{
    
    use case def MonitorEnvironment {
        //subject hapSystem : HAPSystem;
        actor environment : Environment;
        actor airframeStructure:platform;
        actor payload:platform;
        objective {
            doc /* The HAP system monitors environmental conditions (e.g., weather, temperature, wind) 
            using its payloads and sensors.
           
               */
        }
    }
    
      use case def 'TransmitDataGround' {
        
          actor environment : Environment;
          actor payload : platform[0..3];
          actor groundStationControl : Person;
          actor researchers : Person;
         objective {
            doc /* The HAP system collects environmental data using up to three payloads, 
             This data is securely transmitted to the  ground station in real-time, enabling timely analysis and  decision-making. 
        
               */
        }
   } 
} 
}
# Out:
# Package HAPUseCaseForData (dd4395df-7245-40f1-ae1a-a2c7766931bd)

# %%
%viz HAPUseCaseForData
